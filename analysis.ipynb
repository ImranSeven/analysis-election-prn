# %%
import pandas as pd

URL = "https://lake.electiondata.my/results_saluran/nsn_se15_ballots.parquet"

df = pd.read_parquet(URL)
print(df.shape)   # (4334, 21)
print(df.dtypes)
df
# Out:
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[17], line 5
#       1 import pandas as pd
#       2
#       3 URL = "https://lake.electiondata.my/results_saluran/nsn_se15_ballots.parquet"
#       4
# ----> 5 df = pd.read_parquet(URL)
#       6 print(df.shape)   # (4334, 21)
#       7 print(df.dtypes)
#       8 df
#
# File /opt/anaconda3/envs/prn_env/lib/python3.12/site-packages/pandas/io/parquet.py:668, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     508 @set_module("pandas")
#     509 def read_parquet(
#     510     path: FilePath | ReadBuffer[bytes],
#    (...)    518     **kwargs,
#     519 ) -> DataFrame:
#     520     """
#     521     Load a parquet object from the file path, returning a DataFrame.
#     522
#    (...)    665     1    4    9
#     666     """
# ...
